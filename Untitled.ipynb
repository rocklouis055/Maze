# %%
from PIL import Image
import numpy as np
import math
import re
from time import time
from random import choice
class Maze:
  def __init__(self,matrix):
    self.matrix=matrix
    self.row=len(matrix)
    self.col=len(matrix[0])
    self.visited=np.zeros((self.row, self.col))
    self.count2=0
    self.count3=0
    self.valid=0
    self.loc=[0,0,0,0]
    self.jstack=[]
    self.nstack=[]
    self.dist=0
  def check(self):
    for i in range(self.row):
      for j in range(self.col):
        if (self.matrix[i][j]==2):
          self.count2+=1
          self.loc[0],self.loc[1]=i,j
        if(self.matrix[i][j]==3): 
          self.count3+=1
          self.loc[2],self.loc[3]=i,j
    if(self.count2==1 and self.count3==1):
      self.valid=1
      print("Valid Maze")
    return(self.valid)
      
  def path(self):
    i=self.loc[0]
    j=self.loc[1]
    self.len=1
    self.count=0
    self.up=0
    self.down=0
    self.left=0
    self.right=0
    while(1):
      self.up=0
      self.down=0
      self.left=0
      self.right=0
      
      if(i==self.loc[2] and j==self.loc[3]):
        print("Found path!")
        break
      elif(i<self.row-1 and self.matrix[i+1][j] and self.visited[i+1][j]!=1):
        self.down+=1
        #i+=1 
      elif(i>0 and self.matrix[i-1][j] and self.visited[i-1][j]!=1):
        self.up+=1
        #i-=1
      elif(j<self.col-1 and self.matrix[i][j+1] and self.visited[i][j+1]!=1):
        self.right+=1
        #j+=1
      elif(j>0 and self.matrix[i][j-1] and self.visited[i][j-1]!=1):
        self.left+=1
        #j-=1
      self.count=self.up+self.down+self.right+self.left
      self.nstack.append([i,j])
      if(self.count>0):
        self.jstack.append([i,j,self.count,len(self.nstack)])
      if(self.right==1):
        j+=1
        self.visited[i][j]=1
      elif(self.down==1):
        i+=1
        self.visited[i][j]=1
      elif(self.up==1):
        i-=1
        self.visited[i][j]=1
      elif(self.left==1):
        j-=1
        self.visited[i][j]=1
      else:
        i,j,self.count,t=self.jstack.pop()
        del self.nstack[t-1:]
    self.temp=[]
    for i in range(self.row):
      self.temp.append([0]*self.col)
    for i,j in self.nstack:
      self.temp[i][j]=1
    return(self.temp)
  def block(self,i,j,count):
    if(i>0 and self.visited[i-1][j]==count):
      self.visited[i-1][j]=0
    elif(i<self.col-1 and self.visited[i+1][j]==count):
      self.visited[i+1][j]=0
    elif(j>0 and self.visited[i][j-1]==count):
      self.visited[i][j-1]=0
    elif(j<self.row-1 and self.visited[i][j+1]==count):
      self.visited[i][j+1]=0
def genimage(maze,solved=None,mul=None,name='maze',minpixel=5,resolution=None,row=None,col=None,solvedpath=[0,255,0],path=[255,255,255],wall=[0,0,0],start=[0,255,0],end=[0,0,255],offset=1,save=0):
  if row==None:
    row=len(maze)
  if col==None:
    col=len(maze[0])
  if mul is None:
    if resolution is None:
      resolution=minpixel*col
      mul=minpixel
    elif resolution<col*minpixel:
      print("Cant generate image!,Change parameters.")
      return(None,None)
    else:
      mul=math.ceil(resolution/col)
  if offset==1:
    row+=4
    col+=4
    a=np.zeros([row*mul,col*mul,3],dtype='uint8')
    for i in range(mul):
      for j in range(row*mul):
        a[j][i]=a[j][(col-1)*mul+i]=wall
      for j in range(col*mul):
        a[i][j]=a[(row-1)*mul+i][j]=wall
  else:
    a=np.zeros([row*mul,col*mul,3],dtype='uint8')
  
  for i in range(2*mul*offset,(row-2*offset)*mul):
    for j in range(2*mul*offset,(col-2*offset)*mul):
      k=maze[(i-2*mul*offset)//mul][(j-2*mul*offset)//mul]
      l=solved[(i-2*mul*offset)//mul][(j-2*mul*offset)//mul]
      if l==1 and k<2:
        a[i][j]=solvedpath
      elif k==1:
        a[i][j]=path
      elif k==2:
        a[i][j]=start
      elif k==3:
        a[i][j]=end
      else:
        a[i][j]=wall
  img = Image.fromarray(a)
  if(save):
    img.save(name+'.png')
  return(img,a)



n,m=map(int,input("Enter the dimention M*N :").split())

initial=[0,0]

def genMaze(n=4,m=4,initial=[0,0],final=None,infivalue=[2,3],save=0,name="UnsolvedMaze"):
  if n*m//4<2:
    print("Cant generate image! Change Parameters.")
    return
  n,m=n//2,m//2
  l=np.ones([m,n],dtype="int")
  f=np.zeros([m*2-1,n*2-1],dtype="int")
  s=[]
  i=initial[0]
  j=initial[1]
  k=[]
  t=[]
  while(1):
    k=[]
    t.append([i,j])
    if(i-1>=0 and l[i-1][j]==1):k.append([i-1,j])
    if(j-1>=0 and l[i][j-1]==1):k.append([i,j-1])
    if(i+1<m and l[i+1][j]==1):k.append([i+1,j])
    if(j+1<n and l[i][j+1]==1):k.append([i,j+1])
    l[i][j]=0
    if len(k)>0:
      s.append([[i,j],k])
      i,j=choice(k)
    if len(k)==0:
      a=s.pop()
      if(a[0]==initial):
        break
      else:
        i,j=a[0]
  pathMaze=[]
  for i in range(1,len(t)):
    for x in range(2*t[i-1][0],2*t[i][0]+1):
      f[x][2*t[i][1]]=1
      pathMaze.append([x,2*t[i][1]])
    for y in range(2*t[i-1][1],2*t[i][1]+1):
      f[2*t[i][0]][y]=1
      pathMaze.append([2*t[i][0],y])
  f[0][0],f[-1][-1]=infivalue
  return(f,pathMaze,t)
k,path,t=genMaze(m=m,n=n)
maze1=Maze(k)
if(maze1.check()):
  temp=maze1.path()

a,b=genimage(maze=k,solved=temp,minpixel=5,offset=1,solvedpath=[255,255,255],wall=[47, 37, 74],path=[255,255,255],end=[200,10,10],save=1)

a,b=genimage(name="final",maze=k,solved=temp,minpixel=5,offset=1,solvedpath=[230, 21, 153],wall=[47, 37, 74],path=[255,255,255],end=[200,10,10],save=1)

size=m*2-1+4
#print(k)
# Import and initialize the pygame library
# Out:
# Enter the dimention M*N :10 10
# Valid Maze
# Found path!

# %%
import pygame
from pygame.locals import *
pygame.display.init()
clock = pygame.time.Clock()
# Set up the drawing window
screen = pygame.display.set_mode([1366,728])
i=0
width = 700
height = 700
size=width/(m-1+4)
window = pygame.display.set_mode((width,height))
bg_img = pygame.image.load('maze.png')
bg_img = pygame.transform.scale(bg_img,(width,height))
window.blit(bg_img,(0,0))
# Run until the user asks to quit
running = True
j=0
import time
font = pygame.font.SysFont(None, 55)
pygame.mixer.init()
pygame.mixer.music.load('music.mp3')
def text_screen(text, color, x, y):
    screen_text = font.render(text, True, color)
    screen.blit(screen_text, [x, y]) 
while running:
    # Did the user click the window close button?
    k,i=t[j]
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            
            running = False
    if t[j][0]-t[j-1][0]<0:
      pygame.draw.rect(screen, (255,255,0),  [2*size*(t[j-1][1]+2),2*size*(t[j-1][0]+2), (size)*2, size+2] )
    if t[j][0]-t[j-1][0]>0:
      pygame.draw.rect(screen, (255,0,255) , [2*size*(t[j-1][1]+2),2*size*(t[j-1][0]+2), (size)*2, size+2] )
    # Draw a solid blue circle in the center
    # Flip the display
    j+=1
    if j==len(t):
        
        screen.fill((0,0,0))
        text_screen("You Won ", (255,0,0), 100, 350)
        break
    pygame.display.flip()
    pygame.display.update()
    clock.tick(10)
# Done! Time to quit.
window = pygame.display.set_mode((width,height))
bg_img = pygame.image.load('maze.png')
bg_img = pygame.transform.scale(bg_img,(width,height))
window.blit(bg_img,(0,0))
running = True
j=1
while running:
    # Did the user click the window close button?
    k,i=maze1.nstack[j]
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            
            running = False
    
    # Fill the background with white
    pygame.draw.rect(screen, (255,0,255), [1+size*(i+2), 1+size*(k+2), size+2, size+2] )
    # Draw a solid blue circle in the center
    # Flip the display
    j+=1
    if j==len(maze1.nstack):
        
        screen.fill((0,0,0))
        text_screen("You Won ", (255,0,0), 100, 350)

        running = False
        j=len(maze1.nstack)-1
    pygame.display.flip()
    pygame.display.update()
    clock.tick(10)
# Done! Time to quit.
pygame.quit()

# %%
pip install pygame
# Out:
# Collecting pygame
#   Using cached pygame-2.1.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.9 MB)
# Installing collected packages: pygame
# Successfully installed pygame-2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pygame
# Out:
# pygame 2.1.2 (SDL 2.0.16, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pygame.display.init()
clock = pygame.time.Clock()
# Set up the drawing window
screen = pygame.display.set_mode([1366,728])
i=0
width = 700
height = 700
size=width/(m-1+4)
window = pygame.display.set_mode((width,height))
bg_img = pygame.image.load('maze.png')
bg_img = pygame.transform.scale(bg_img,(width,height))
window.blit(bg_img,(0,0))
# Run until the user asks to quit
running = True
j=0
import time
font = pygame.font.SysFont(None, 55)

# %%
import pygame
pygame.display.init()
run=True
#screensize
screensize = (width,height)=(600,600)
screen = pygame.display.set_mode(screensize)

#font used for the text
myfont = pygame.font.SysFont('Comic Sans MS', 30)
#the text that will be rendered. It is usually some variable value, but the problem remains even if it is constant:
vel=3.001


while run:
    pygame.time.delay(20)
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            run=False 
    screen.fill((0,0,0))
    ########rendering the text############
    textsurface = myfont.render(str(int(vel)), False, (0, 100, 100))
    screen.blit(textsurface,(200,400))
    ######################################

    pygame.display.update()

pygame.display.quit()

# %%
pygame.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 pygame.quit()
#
# NameError: name 'pygame' is not defined

# %%
# !jupyter notebook --debug
# Out:
# [D 23:52:17.107 NotebookApp] Searching ['/home/louise/Desktop/pygame', '/home/louise/.jupyter', '/home/louise/.local/etc/jupyter', '/home/louise/anaconda3/etc/jupyter', '/usr/local/etc/jupyter', '/etc/jupyter'] for config files
# [D 23:52:17.107 NotebookApp] Looking for jupyter_config in /etc/jupyter
# [D 23:52:17.107 NotebookApp] Looking for jupyter_config in /usr/local/etc/jupyter
# [D 23:52:17.107 NotebookApp] Looking for jupyter_config in /home/louise/anaconda3/etc/jupyter
# [D 23:52:17.107 NotebookApp] Looking for jupyter_config in /home/louise/.local/etc/jupyter
# [D 23:52:17.107 NotebookApp] Looking for jupyter_config in /home/louise/.jupyter
# [D 23:52:17.107 NotebookApp] Looking for jupyter_config in /home/louise/Desktop/pygame
# [D 23:52:17.109 NotebookApp] Looking for jupyter_notebook_config in /etc/jupyter
# [D 23:52:17.109 NotebookApp] Looking for jupyter_notebook_config in /usr/local/etc/jupyter
# [D 23:52:17.109 NotebookApp] Looking for jupyter_notebook_config in /home/louise/anaconda3/etc/jupyter
# [D 23:52:17.109 NotebookApp] Loaded config file: /home/louise/anaconda3/etc/jupyter/jupyter_notebook_config.json
# [D 23:52:17.109 NotebookApp] Looking for jupyter_notebook_config in /home/louise/.local/etc/jupyter
# [D 23:52:17.110 NotebookApp] Looking for jupyter_notebook_config in /home/louise/.jupyter
# [D 23:52:17.110 NotebookApp] Looking for jupyter_notebook_config in /home/louise/Desktop/pygame
# [D 23:52:17.116 NotebookApp] Paths used for configuration of jupyter_notebook_config:
#     	/etc/jupyter/jupyter_notebook_config.json
# [D 23:52:17.117 NotebookApp] Paths used for configuration of jupyter_notebook_config:
#     	/usr/local/etc/jupyter/jupyter_notebook_config.json
# [D 23:52:17.118 NotebookApp] Paths used for configuration of jupyter_notebook_config:
#     	/home/louise/anaconda3/etc/jupyter/jupyter_notebook_config.d/jupyterlab.json
#     	/home/louise/anaconda3/etc/jupyter/jupyter_notebook_config.json
# [D 23:52:17.119 NotebookApp] Paths used for configuration of jupyter_notebook_config:
#     	/home/louise/.local/etc/jupyter/jupyter_notebook_config.json
# [D 23:52:17.119 NotebookApp] Paths used for configuration of jupyter_notebook_config:
#     	/home/louise/.jupyter/jupyter_notebook_config.json
# [W 23:52:17.383 NotebookApp] Error loading server extension jupyterlab
#     Traceback (most recent call last):
#       File "/home/louise/anaconda3/lib/python3.9/site-packages/notebook/notebookapp.py", line 2025, in init_server_extensions
#         mod = importlib.import_module(modulename)
#       File "/home/louise/anaconda3/lib/python3.9/importlib/__init__.py", line 127, in import_module
#         return _bootstrap._gcd_import(name[level:], package, level)
#       File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#       File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#       File "<frozen importlib._bootstrap>", line 984, in _find_and_load_unlocked
#     ModuleNotFoundError: No module named 'jupyterlab'
# [I 23:52:17.391 NotebookApp] The port 8888 is already in use, trying another port.
# [I 23:52:17.391 NotebookApp] The port 8889 is already in use, trying another port.
# [I 23:52:17.392 NotebookApp] Serving notebooks from local directory: /home/louise/Desktop/pygame
# [I 23:52:17.392 NotebookApp] Jupyter Notebook 6.4.12 is running at:
# [I 23:52:17.392 NotebookApp] http://localhost:8890/?token=7e1b4a86c7621652d75c1b7ab533110d1e500a5a3577c3ea
# [I 23:52:17.392 NotebookApp]  or http://127.0.0.1:8890/?token=7e1b4a86c7621652d75c1b7ab533110d1e500a5a3577c3ea
# [I 23:52:17.392 NotebookApp] Use Control-C to stop this server and shut down all kernels (twice to skip confirmation).
# [C 23:52:17.415 NotebookApp]
#
#     To access the notebook, open this file in a browser:
#         file:///home/louise/.local/share/jupyter/runtime/nbserver-41301-open.html
#     Or copy and paste one of these URLs:
#         http://localhost:8890/?token=7e1b4a86c7621652d75c1b7ab533110d1e500a5a3577c3ea
#      or http://127.0.0.1:8890/?token=7e1b4a86c7621652d75c1b7ab533110d1e500a5a3577c3ea
# [D 23:52:20.721 NotebookApp] Accepting token-authenticated connection from 127.0.0.1
# [D 23:52:20.723 NotebookApp] Using contents: services/contents
# [D 23:52:20.814 NotebookApp] Path base/images/favicon.ico served from /home/louise/anaconda3/lib/python3.9/site-packages/notebook/static/base/images/favicon.ico
# [D 23:52:20.814 NotebookApp] Path components/jquery-ui/themes/smoothness/jquery-ui.min.css served from /home/louise/anaconda3/lib/python3.9/site-packages/notebook/static/components/jquery-ui/themes/smoothness/jquery-ui.min.css
# [D 23:52:20.815 NotebookApp] Path components/jquery-typeahead/dist/jquery.typeahead.min.css served from /home/louise/anaconda3/lib/python3.9/site-packages/notebook/static/components/jquery-typeahead/dist/jquery.typeahead.min.css
# [D 23:52:20.815 NotebookApp] Path style/style.min.css served from /home/louise/anaconda3/lib/python3.9/site-packages/notebook/static
favicon.ico?v=50afa725b5de8b00030139d09b38620224d4e7dba47c07ef0e86d4643f30c9bfe6bb7e1a4a1c561aa32834480909a4b6fe7cd1e17f7159330b6b5914bf45a880 (127.0.0.1) 1.410000ms
# [D 23:52:22.375 NotebookApp] Paths used for configuration of tree:
#     	/etc/jupyter/nbconfig/tree.json
# [D 23:52:22.376 NotebookApp] Paths used for configuration of tree:
#     	/usr/local/etc/jupyter/nbconfig/tree.json
# [D 23:52:22.377 NotebookApp] Paths used for configuration of tree:
#     	/home/louise/anaconda3/etc/jupyter/nbconfig/tree.json
# [D 23:52:22.378 NotebookApp] Paths used for configuration of tree:
#     	/home/louise/.local/etc/jupyter/nbconfig/tree.json
# [D 23:52:22.379 NotebookApp] Paths used for configuration of tree:
#     	/home/louise/.jupyter/nbconfig/tree.json
# [D 23:52:22.379 NotebookApp] 200 GET /api/config/tree?_=1658773341972 (127.0.0.1) 6.480000ms
# [D 23:52:22.387 NotebookApp] Paths used for configuration of common:
#     	/etc/jupyter/nbconfig/common.json
# [D 23:52:22.387 NotebookApp] Paths used for configuration of common:
#     	/usr/local/etc/jupyter/nbconfig/common.json
# [D 23:52:22.389 NotebookApp] Paths used for configuration of common:
#     	/home/louise/anaconda3/etc/jupyter/nbconfig/common.json
# [D 23:52:22.389 NotebookApp] Paths used for configuration of common:
#     	/home/louise/.local/etc/jupyter/nbconfig/common.json
# [D 23:52:22.390 NotebookApp] Paths used for configuration of common:
#     	/home/louise/.jupyter/nbconfig/common.json
# [D 23:52:22.391 NotebookApp] 200 GET /api/config/common?_=1658773341973 (127.0.0.1) 6.020000ms
# [D 23:52:22.440 NotebookApp] 200 GET /api/terminals?_=1658773341974 (127.0.0.1) 1.170000ms
# [D 23:52:22.442 NotebookApp] Found kernel python3 in /home/louise/anaconda3/share/jupyter/kernels
# [D 23:52:22.858 NotebookApp] 200 GET /api/kernelspecs (127.0.0.1) 417.060000ms
# [D 23:52:22.862 NotebookApp] 200 GET /api/sessions?_=1658773341975 (127.0.0.1) 2.880000ms
# [D 23:52:22.863 NotebookApp] 200 GET /api/terminals?_=1658773341976 (127.0.0.1) 3.140000ms
# [D 23:52:22.865 NotebookApp] Path components/font-awesome/fonts/fontawesome-webfont.woff2 served from /home/louise/anaconda3/lib/python3.9/site-packages/notebook/static/components/font-awesome/fonts/fontawesome-webfont.woff2
# [D 23:52:22.875 NotebookApp] 200 GET /static/components/font-awesome/fonts/fontawesome-webfont.woff2?v=4.7.0 (127.0.0.1) 10.500000ms
# [D 23:52:22.890 NotebookApp] 200 GET /api/contents?type=directory&_=1658773341977 (127.0.0.1) 4.310000ms
# [D 23:52:23.244 NotebookApp] Path custom.js served from /home/louise/anaconda3/lib/python3.9/site-packages/notebook/static/custom/custom.js
# [D 23:52:23.244 NotebookApp] 200 GET /custom/custom.js?v=20220725235217 (127.0.0.1) 1.420000ms
# ^C
# [I 23:52:36.031 NotebookApp] interrupted
# Serving notebooks from local directory: /home/louise/Desktop/pygame
# 0 active kernels
# Jupyter Notebook 6.4.12 is running at:
# http://localhost:8890/?token=7e1b4a86c7621652d75c1b7ab533110d1e500a5a3577c3ea
#  or http://127.0.0.1:8890/?token=7e1b4a86c7621652d75c1b7ab533110d1e500a5a3577c3ea
# Shutdown this notebook server (y/[n])? resuming operation...
